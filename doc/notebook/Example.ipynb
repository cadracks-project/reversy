# %%
import ccad.model as cm 
import ccad.planarnet as pn
import numpy as np
import matplotlib.pyplot as plt
import reversy.reversy as reversy
from OCC.Display.WebGl import jupyter_renderer
# %matplotlib inline
# Out:
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/OCC/BRepBuilderAPI.py:3: DeprecationWarning: OCC.BRepBuilderAPI is deprecated since pythonocc-0.18.2. Use OCC.Core.BRepBuilderAPI
#   warnings.warn("OCC.BRepBuilderAPI is deprecated since pythonocc-0.18.2. Use OCC.Core.BRepBuilderAPI", DeprecationWarning)
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/OCC/BRep.py:3: DeprecationWarning: OCC.BRep is deprecated since pythonocc-0.18.2. Use OCC.Core.BRep
#   warnings.warn("OCC.BRep is deprecated since pythonocc-0.18.2. Use OCC.Core.BRep", DeprecationWarning)
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/OCC/BRepTopAdaptor.py:3: DeprecationWarning: OCC.BRepTopAdaptor is deprecated since pythonocc-0.18.2. Use OCC.Core.BRepTopAdaptor
#   warnings.warn("OCC.BRepTopAdaptor is deprecated since pythonocc-0.18.2. Use OCC.Core.BRepTopAdaptor", DeprecationWarning)
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/OCC/BRepFill.py:3: DeprecationWarning: OCC.BRepFill is deprecated since pythonocc-0.18.2. Use OCC.Core.BRepFill
#   warnings.warn("OCC.BRepFill is deprecated since pythonocc-0.18.2. Use OCC.Core.BRepFill", DeprecationWarning)
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/OCC/Geom.py:3: DeprecationWarning: OCC.Geom is deprecated since pythonocc-0.18.2. Use OCC.Core.Geom
#   warnings.warn("OCC.Geom is deprecated since pythonocc-0.18.2. Use OCC.Core.Geom", DeprecationWarning)
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/OCC/GeomAbs.py:3: DeprecationWarning: OCC.GeomAbs is deprecated since pythonocc-0.18.2. Use OCC.Core.GeomAbs
#   warnings.warn("OCC.GeomAbs is deprecated since pythonocc-0.18.2. Use OCC.Core.GeomAbs", DeprecationWarning)
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/OCC/GeomAPI.py:3: DeprecationWarning: OCC.GeomAPI is deprecated since pythonocc-0.18.2. Use OCC.Core.GeomAPI
#   warnings.warn("OCC.GeomAPI is deprecated since pythonocc-0.18.2. Use OCC.Core.GeomAPI", DeprecationWarning)
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/OCC/GeomLib.py:3: DeprecationWarning: OCC.GeomLib is deprecated since pythonocc-0.18.2. Use OCC.Core.GeomLib
#   warnings.warn("OCC.GeomLib is deprecated since pythonocc-0.18.2. Use OCC.Core.GeomLib", DeprecationWarning)
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/OCC/TopAbs.py:3: DeprecationWarning: OCC.TopAbs is deprecated since pythonocc-0.18.2. Use OCC.Core.TopAbs
#   warnings.warn("OCC.TopAbs is deprecated since pythonocc-0.18.2. Use OCC.Core.TopAbs", DeprecationWarning)
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/OCC/TopExp.py:3: DeprecationWarning: OCC.TopExp is deprecated since pythonocc-0.18.2. Use OCC.Core.TopExp
#   warnings.warn("OCC.TopExp is deprecated since pythonocc-0.18.2. Use OCC.Core.TopExp", DeprecationWarning)
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/OCC/TopoDS.py:3: DeprecationWarning: OCC.TopoDS is deprecated since pythonocc-0.18.2. Use OCC.Core.TopoDS
#   warnings.warn("OCC.TopoDS is deprecated since pythonocc-0.18.2. Use OCC.Core.TopoDS", DeprecationWarning)
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/OCC/GeomLProp.py:3: DeprecationWarning: OCC.GeomLProp is deprecated since pythonocc-0.18.2. Use OCC.Core.GeomLProp
#   warnings.warn("OCC.GeomLProp is deprecated since pythonocc-0.18.2. Use OCC.Core.GeomLProp", DeprecationWarning)
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/OCC/BRepTools.py:3: DeprecationWarning: OCC.BRepTools is deprecated since pythonocc-0.18.2. Use OCC.Core.BRepTools
#   warnings.warn("OCC.BRepTools is deprecated since pythonocc-0.18.2. Use OCC.Core.BRepTools", DeprecationWarning)
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/OCC/BRepAdaptor.py:3: DeprecationWarning: OCC.BRepAdaptor is deprecated since pythonocc-0.18.2. Use OCC.Core.BRepAdaptor
#   warnings.warn("OCC.BRepAdaptor is deprecated since pythonocc-0.18.2. Use OCC.Core.BRepAdaptor", DeprecationWarning)
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/OCC/ShapeAnalysis.py:3: DeprecationWarning: OCC.ShapeAnalysis is deprecated since pythonocc-0.18.2. Use OCC.Core.ShapeAnalysis
#   warnings.warn("OCC.ShapeAnalysis is deprecated since pythonocc-0.18.2. Use OCC.Core.ShapeAnalysis", DeprecationWarning)
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/OCC/GeomProjLib.py:3: DeprecationWarning: OCC.GeomProjLib is deprecated since pythonocc-0.18.2. Use OCC.Core.GeomProjLib
#   warnings.warn("OCC.GeomProjLib is deprecated since pythonocc-0.18.2. Use OCC.Core.GeomProjLib", DeprecationWarning)
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/OCC/Adaptor3d.py:3: DeprecationWarning: OCC.Adaptor3d is deprecated since pythonocc-0.18.2. Use OCC.Core.Adaptor3d
#   warnings.warn("OCC.Adaptor3d is deprecated since pythonocc-0.18.2. Use OCC.Core.Adaptor3d", DeprecationWarning)
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/OCC/gp.py:3: DeprecationWarning: OCC.gp is deprecated since pythonocc-0.18.2. Use OCC.Core.gp
#   warnings.warn("OCC.gp is deprecated since pythonocc-0.18.2. Use OCC.Core.gp", DeprecationWarning)
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/OCC/BRepCheck.py:3: DeprecationWarning: OCC.BRepCheck is deprecated since pythonocc-0.18.2. Use OCC.Core.BRepCheck
#   warnings.warn("OCC.BRepCheck is deprecated since pythonocc-0.18.2. Use OCC.Core.BRepCheck", DeprecationWarning)
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/OCC/GeomPlate.py:3: DeprecationWarning: OCC.GeomPlate is deprecated since pythonocc-0.18.2. Use OCC.Core.GeomPlate
#   warnings.warn("OCC.GeomPlate is deprecated since pythonocc-0.18.2. Use OCC.Core.GeomPlate", DeprecationWarning)
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/OCC/GCPnts.py:3: DeprecationWarning: OCC.GCPnts is deprecated since pythonocc-0.18.2. Use OCC.Core.GCPnts
#   warnings.warn("OCC.GCPnts is deprecated since pythonocc-0.18.2. Use OCC.Core.GCPnts", DeprecationWarning)
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/OCC/BRepLProp.py:3: DeprecationWarning: OCC.BRepLProp is deprecated since pythonocc-0.18.2. Use OCC.Core.BRepLProp
#   warnings.warn("OCC.BRepLProp is deprecated since pythonocc-0.18.2. Use OCC.Core.BRepLProp", DeprecationWarning)
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/OCC/BRepIntCurveSurface.py:3: DeprecationWarning: OCC.BRepIntCurveSurface is deprecated since pythonocc-0.18.2. Use OCC.Core.BRepIntCurveSurface
#   warnings.warn("OCC.BRepIntCurveSurface is deprecated since pythonocc-0.18.2. Use OCC.Core.BRepIntCurveSurface", DeprecationWarning)
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/OCC/ShapeBuild.py:3: DeprecationWarning: OCC.ShapeBuild is deprecated since pythonocc-0.18.2. Use OCC.Core.ShapeBuild
#   warnings.warn("OCC.ShapeBuild is deprecated since pythonocc-0.18.2. Use OCC.Core.ShapeBuild", DeprecationWarning)
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/OCC/GeomAdaptor.py:3: DeprecationWarning: OCC.GeomAdaptor is deprecated since pythonocc-0.18.2. Use OCC.Core.GeomAdaptor
#   warnings.warn("OCC.GeomAdaptor is deprecated since pythonocc-0.18.2. Use OCC.Core.GeomAdaptor", DeprecationWarning)
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/OCC/Approx.py:3: DeprecationWarning: OCC.Approx is deprecated since pythonocc-0.18.2. Use OCC.Core.Approx
#   warnings.warn("OCC.Approx is deprecated since pythonocc-0.18.2. Use OCC.Core.Approx", DeprecationWarning)
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/OCC/GeomConvert.py:3: DeprecationWarning: OCC.GeomConvert is deprecated since pythonocc-0.18.2. Use OCC.Core.GeomConvert
#   warnings.warn("OCC.GeomConvert is deprecated since pythonocc-0.18.2. Use OCC.Core.GeomConvert", DeprecationWarning)
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/OCC/Quantity.py:3: DeprecationWarning: OCC.Quantity is deprecated since pythonocc-0.18.2. Use OCC.Core.Quantity
#   warnings.warn("OCC.Quantity is deprecated since pythonocc-0.18.2. Use OCC.Core.Quantity", DeprecationWarning)
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/OCC/AIS.py:3: DeprecationWarning: OCC.AIS is deprecated since pythonocc-0.18.2. Use OCC.Core.AIS
#   warnings.warn("OCC.AIS is deprecated since pythonocc-0.18.2. Use OCC.Core.AIS", DeprecationWarning)
# /home/uguen/Apps/pythreejs/pythreejs/traits.py:50: DeprecationWarning: Traits should be given as instances, not types (for example, `Int()`, not `Int`) Passing types is deprecated in traitlets 4.1.
#   super(Vector3, self).__init__(*(trait, trait, trait), default_value=default_value, **kwargs)
# /home/uguen/Apps/pythreejs/pythreejs/core/Geometry_autogen.py:32: DeprecationWarning: metadata {'trait': <pythreejs.traits.Face3 object at 0x7fe7de4eb690>} was set from the constructor. With traitlets 4.1, metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   faces = Tuple(trait=Face3()).tag(sync=True)
# /home/uguen/Apps/pythreejs/pythreejs/pythreejs.py:56: DeprecationWarning: Traits should be given as instances, not types (for example, `Int()`, not `Int`). Passing types is deprecated in traitlets 4.1.
#   z = List(CFloat, [0] * 100)
# SMESH wrapper not found, can't display SMESH meshes

# %%
filename = "../../step/ASM0001_ASM_1_ASM.stp"

# %%
a1 = reversy.reverse(filename,view=False)
# Out:
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/reversy-0.1-py2.7.egg/reversy/reversy.py:682: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/reversy-0.1-py2.7.egg/reversy/reversy.py:683: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/reversy-0.1-py2.7.egg/reversy/reversy.py:684: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/reversy-0.1-py2.7.egg/reversy/reversy.py:685: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/reversy-0.1-py2.7.egg/reversy/reversy.py:686: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/reversy-0.1-py2.7.egg/reversy/reversy.py:721: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# equal_sim_nodes_edges
# delete_edges
# intersect_nodes_edges
# save json

# %%
a1
# Out:
# 10 nodes
# ___637#566#58___1
# ___637#566#58___1
# ___105#95#4___1
# ___105#95#4___1
# ___105#95#4___1
# ___105#95#4___1
# ___240#121#162___1
# ___240#121#163___1
# ___117#114#38___1
# ___117#114#38___1

# %% [raw]
# s,j = a1.view(jupyter=True)

# %%
a1.show_graph(blabels=False,figsize=(10,10))
# Out:
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/networkx/drawing/nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/networkx/drawing/nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/matplotlib/__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# /home/uguen/anaconda2/envs/ccad/lib/python2.7/site-packages/matplotlib/rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
#   warnings.warn("axes.hold is deprecated, will be removed in 3.0")

# %%
a1.df_nodes
# Out:
#                  name count         nodes   volume assembly
# 0   ___637#566#58___1     2        [0, 1]   423116    False
# 1     ___105#95#4___1     4  [2, 3, 4, 5]  33497.5    False
# 2  ___240#121#162___1     1           [6]  94171.5    False
# 3  ___240#121#163___1     1           [7]  94171.6    False
# 4   ___117#114#38___1     2        [8, 9]  27993.5    False

# %%
a1.edge
# Out:
# {0: {},
#  1: {0: {'close': False, 'equal': False, 'intersect': False, 'sim': True}},
#  2: {0: {'close': True, 'equal': False, 'intersect': False, 'sim': False}},
#  3: {1: {'close': True, 'equal': False, 'intersect': False, 'sim': False},
#   2: {'close': False,
#    'djk': 2.1316282072803006e-12,
#    'equal': True,
#    'intersect': False,
#    'sim': True}},
#  4: {0: {'close': True, 'equal': False, 'intersect': False, 'sim': False},
#   2: {'close': False,
#    'djk': 3.0695446184836328e-12,
#    'equal': True,
#    'intersect': False,
#    'sim': True}},
#  5: {1: {'close': True, 'equal': False, 'intersect': False, 'sim': False},
#   2: {'close': False,
#    'djk': 6.6506800067145377e-12,
#    'equal': True,
#    'intersect': False,
#    'sim': True}},
#  6: {0: {'close': True, 'equal': False, 'intersect': True, 'sim': False}},
#  7: {1: {'close': True, 'equal': False, 'intersect': True, 'sim': False},
#   6: {'close': False, 'equal': False, 'intersect': False, 'sim': True}},
#  8: {0: {'close': True, 'equal': False, 'intersect': True, 'sim': False},
#   6: {'close': True, 'equal': False, 'intersect': True, 'sim': False}},
#  9: {1: {'close': True, 'equal': False, 'intersect': True, 'sim': False},
#   7: {'close': True, 'equal': False, 'intersect': True, 'sim': False},
#   8: {'close': False, 'equal': False, 'intersect': False, 'sim': True}}}

# %%
for e in a1.edges():
    print e[0],e[1],a1.edge[e[0]][e[1]]
# Out:
# 1 0 {'close': False, 'equal': False, 'sim': True, 'intersect': False}
# 2 0 {'close': True, 'equal': False, 'intersect': False, 'sim': False}
# 3 1 {'close': True, 'equal': False, 'intersect': False, 'sim': False}
# 3 2 {'close': False, 'djk': 2.1316282072803006e-12, 'equal': True, 'sim': True, 'intersect': False}
# 4 0 {'close': True, 'equal': False, 'intersect': False, 'sim': False}
# 4 2 {'close': False, 'djk': 3.0695446184836328e-12, 'equal': True, 'sim': True, 'intersect': False}
# 5 1 {'close': True, 'equal': False, 'intersect': False, 'sim': False}
# 5 2 {'close': False, 'djk': 6.6506800067145377e-12, 'equal': True, 'sim': True, 'intersect': False}
# 6 0 {'close': True, 'equal': False, 'intersect': True, 'sim': False}
# 7 1 {'close': True, 'equal': False, 'intersect': True, 'sim': False}
# 7 6 {'close': False, 'equal': False, 'sim': True, 'intersect': False}
# 8 0 {'close': True, 'equal': False, 'intersect': True, 'sim': False}
# 8 6 {'close': True, 'equal': False, 'intersect': True, 'sim': False}
# 9 8 {'close': False, 'equal': False, 'sim': True, 'intersect': False}
# 9 1 {'close': True, 'equal': False, 'intersect': True, 'sim': False}
# 9 7 {'close': True, 'equal': False, 'intersect': True, 'sim': False}

# %%
A = a1.merge_nodes([1,7,9,3,5])

# %%
a1.node[10]
# Out:
# {'V': array([[ 1.,  0.,  0.],
#         [ 0.,  1.,  0.],
#         [ 0.,  0.,  1.]]),
#  'assembly': True,
#  'name': '705#456#167',
#  'pc': array([0, 0, 0]),
#  'sig': '705#456#167',
#  'volume': 94988.54732647975}
